# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy import Matrix, init_printing
from scipy.stats import norm

# %% [markdown]
# First let's set the parametes:
# $\rho$=0.95
# $\sigma$=0.007

# %%
rho=0.95
sigma=0.007
n=9

# %% [markdown]
# a)
#
# Now we'll find the upper and lower bound of the grid, by Tauchen's method.
# $$\theta_N=m\frac{\sigma}{\sqrt{1-\rho^2}}$$
# $$\theta_1=-m\frac{\sigma}{\sqrt{1-\rho^2}}$$
# To be conservative I will use m = 3

# %%
m=3
upp=m*sigma/(1-rho**2)**0.5
low=-upp

# %% [markdown]
# Now let's generate equidistant points, as well as the grid "separators", compute the cdfs of the limits we have created for our state spaces, then create the Markov chain transition matrix, this is all done with the function built bellow "tau", and the np.space fuction

# %%
def tau(n,rho,sigma,a,b):
    xgrid = np.linspace(low, upp,n )
    def grid(a,b,n):
        w=((np.sqrt(b-a))**2)/(n-1)
        x=np.empty(n-1)
        x[0]=a+w/2
        x[n-2]=b-w/2
        for i in range (n-3):
            x[i+1]=x[i]+w
        return x
    y=grid(a,b,n)
    trm = np.zeros((n, n-1))
    for j in range(n-1):
        for i in range(n):     
            trm[i, j] = norm.cdf(y[j],loc=rho*xgrid[i],scale=sigma)
    trmo=np.zeros((n,n))
    for i in range(n): 
        trmo[i,0]=trm[i,0]
        trmo[i,n-1]=1-trm[i,n-2]
        for j in range(n-2):
            trmo[i,j+1]=trm[i,j+1]-trm[i,j]
    return trmo
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)

# %%
def show(X):
    init_printing()
    display(Matrix(np.round(X,5)))
print("Tauchen's method transition matrix:")

show(trmo)
# Out:
# Tauchen's method transition matrix:
# ⎡0.76442  0.23469  0.0009      0        0        0        0        0        0
# ⎢
# ⎢0.05923  0.7405   0.19967  0.00059     0        0        0        0        0
# ⎢
# ⎢6.0e-5   0.07471  0.7569   0.16795  0.00039     0        0        0        0
# ⎢
# ⎢   0     0.0001   0.09314  0.76688  0.13963  0.00025     0        0        0
# ⎢
# ⎢   0        0     0.00016  0.11473  0.77023  0.11473  0.00016     0        0
# ⎢
# ⎢   0        0        0     0.00025  0.13963  0.76688  0.09314  0.0001      0
# ⎢
# ⎢   0        0        0        0     0.00039  0.16795  0.7569   0.07471  6.0e-
# ⎢
# ⎢   0        0        0        0        0     0.00059  0.19967  0.7405   0.059
# ⎢
# ⎣   0        0        0        0        0        0     0.0009   0.23469  0.764
#
#   ⎤
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
# 5 ⎥
#   ⎥
# 23⎥
#   ⎥
# 42⎦

# %% [markdown]
# b)
#
# The rouwenhost method is based on a different grid and matrix using the following logic:
#
# $$\theta_N=\sigma_\theta \sqrt{N-1} \quad \theta_1=-\theta_N \quad where \quad \sigma_\theta^2=\frac{\sigma^2}{1-\rho^2}$$
#
#
# $$
# P_N=p\left[\begin{array}{cc}
# P_{N-1} & 0 \\
# \mathbf{0}^{\prime} & 0
# \end{array}\right]+(1-p)\left[\begin{array}{cc}
# \mathbf{0} & P_{N-1} \\
# 0 & \mathbf{0}^{\prime}
# \end{array}\right]+(1-p)\left[\begin{array}{cc}
# \mathbf{0}^{\prime} & 0 \\
# P_{N-1} & \mathbf{0}
# \end{array}\right]+p\left[\begin{array}{cc}
# 0 & \mathbf{0}^{\prime} \\
# \mathbf{0} & P_{N-1}
# \end{array}\right]
# $$
# $$p=\frac{1+\rho}{2}, P_2=\left[\begin{array}{cc}p & 1-p \\ 1-p & p\end{array}\right]$$

# %% [markdown]
# Now i create another fuction to get this matrix:

# %%
def rouwenhorst(n, rho,sigma):
    p = (1 + rho) / 2
    maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
    mini=-maxi
    if n == 2:
        theta = np.array([[p, 1 - p], [1 - p, p]])

    else :
        p1 = np.zeros((n, n))
        p2 = np.zeros((n, n))
        p3 = np.zeros((n, n))
        p4 = np.zeros((n, n))

        new_mat = rouwenhorst(n - 1, rho, sigma)

        p1[:n - 1, :n - 1] = p * new_mat
        p2[:n - 1, 1:] = (1 - p) * new_mat
        p3[1:, :-1] = (1 - p) * new_mat
        p4[1:, 1:] = p * new_mat

        theta = p1 + p2 + p3 + p4
        for i in range (n):
            theta[i: ,:] = (theta[i:,:] / sum(theta[i]))

    return theta
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)

# %%
print("ROU method transition matrix:")

show(trm1)
# Out:
# ROU method transition matrix:
# ⎡0.81665  0.16752  0.01503  0.00077  2.0e-5      0        0        0        0
# ⎢
# ⎢0.02094  0.82041  0.14687  0.01129  0.00048  1.0e-5      0        0        0
# ⎢
# ⎢0.00054  0.04196  0.8231   0.12605  0.00807  0.00028  1.0e-5      0        0
# ⎢
# ⎢1.0e-5   0.00161  0.06303  0.82472  0.10511  0.00538  0.00014     0        0
# ⎢
# ⎢   0     6.0e-5   0.00323  0.08409  0.82526  0.08409  0.00323  6.0e-5      0
# ⎢
# ⎢   0        0     0.00014  0.00538  0.10511  0.82472  0.06303  0.00161  1.0e-
# ⎢
# ⎢   0        0     1.0e-5   0.00028  0.00807  0.12605  0.8231   0.04196  0.000
# ⎢
# ⎢   0        0        0     1.0e-5   0.00048  0.01129  0.14687  0.82041  0.020
# ⎢
# ⎣   0        0        0        0     2.0e-5   0.00077  0.01503  0.16752  0.816
#
#   ⎤
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
# 5 ⎥
#   ⎥
# 54⎥
#   ⎥
# 94⎥
#   ⎥
# 65⎦

# %% [markdown]
# The  matrix's presented above only display the first five digits after the dot, this was made for visual reasons, the trmo and trm1 matrix's that contain the full numbers (and add up to 1 in each row) is what is going to be used for calculations.
#
# (If interested the amount of numbers after the dot can be changed in the show function)

# %% [markdown]
# c)
#
# Now we can simulate the process, starting with the continuous one to get its shocks:

# %%
np.random.seed(1658)
x=np.empty(1001)
x[0]=0
alpha=0.95
T=1000
shocks=np.random.normal(size=1000,scale=0.007)
for t in range(T):
    x[t+1]=x[t]*alpha + shocks[t]
plt.plot(x, label='AR[1]')
plt.legend()
plt.show()

# %% [markdown]
# We then get the cdf of the shocks, and choose the next state if the process in the discrete case as the first one that the sum of the transition matrix of the current step (starting from the left)

# %%
shocks_cdf= norm.cdf(shocks,scale=sigma)
nsteps = 1001
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]

plt.plot(simulated_states, label='tauchen')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states, label='Tauchens')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %%
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]

plt.plot(simulated_states1, label='rouse')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states1, label='Rou')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# The graphs are kind off close but let's try n=21

# %%
n=21

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]

plt.plot(simulated_states, label='tauchen')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states, label='Tauchens')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# It is clear that we got much closer to the real distribuition, let's see with Rou

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]

plt.plot(simulated_states1, label='rouse')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states1, label='Rou')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# It is also much closer to the "real" distribution

# %% [markdown]
# d)
#
# Let's go back to n=9 ang do the regression:

# %%
from sklearn.linear_model import LinearRegression

# %%
n=9

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]
model = LinearRegression()
model.fit(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")

# %% [markdown]
# The regression came out pretty acurate, let's checke for row

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]
model = LinearRegression()
model.fit(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")

# %% [markdown]
# It is still pretty good, but let's try with n=21

# %%
n=21

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]
model = LinearRegression()
model.fit(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.0003056]
# Coefficients: [[0.94473247]]
# coefficient of determination: 0.8925194392857947

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]
model = LinearRegression()
model.fit(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.00051402]
# Coefficients: [[0.94779021]]
# coefficient of determination: 0.8983062802922439

# %% [markdown]
# They both came out better

# %% [markdown]
# e)
# doing it again for:
# $\rho$=0.99

# %%
rho=0.99
n=9

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
show(trmo)
# Out:
# ⎡0.8654   0.13438  0.00023     0        0        0        0        0        0
# ⎢
# ⎢0.10151  0.76903  0.12926  0.00021     0        0        0        0        0
# ⎢
# ⎢0.00013  0.1057   0.7697   0.12428  0.00019     0        0        0        0
# ⎢
# ⎢   0     0.00014  0.11015  0.7701   0.11944  0.00017     0        0        0
# ⎢
# ⎢   0        0     0.00016  0.11473  0.77023  0.11473  0.00016     0        0
# ⎢
# ⎢   0        0        0     0.00017  0.11944  0.7701   0.11015  0.00014     0
# ⎢
# ⎢   0        0        0        0     0.00019  0.12428  0.7697   0.1057   0.000
# ⎢
# ⎢   0        0        0        0        0     0.00021  0.12926  0.76903  0.101
# ⎢
# ⎣   0        0        0        0        0        0     0.00023  0.13438  0.865
#
#   ⎤
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
# 13⎥
#   ⎥
# 51⎥
#   ⎥
# 4 ⎦

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
show(trm1)
# Out:
# ⎡0.96069  0.03862  0.00068  1.0e-5      0        0        0        0        0
# ⎢
# ⎢0.00483  0.96086  0.0338   0.00051     0        0        0        0        0
# ⎢
# ⎢2.0e-5   0.00966  0.96098  0.02897  0.00036     0        0        0        0
# ⎢
# ⎢   0     7.0e-5   0.01448  0.96106  0.02414  0.00024     0        0        0
# ⎢
# ⎢   0        0     0.00015  0.01931  0.96108  0.01931  0.00015     0        0
# ⎢
# ⎢   0        0        0     0.00024  0.02414  0.96106  0.01448  7.0e-5      0
# ⎢
# ⎢   0        0        0        0     0.00036  0.02897  0.96098  0.00966  2.0e-
# ⎢
# ⎢   0        0        0        0        0     0.00051  0.0338   0.96086  0.004
# ⎢
# ⎣   0        0        0        0        0     1.0e-5   0.00068  0.03862  0.960
#
#   ⎤
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
#   ⎥
# 5 ⎥
#   ⎥
# 83⎥
#   ⎥
# 69⎦

# %% [markdown]
# Now simulating a new AR[1] process and comparing to the simulations of tauchens and row's

# %%
np.random.seed(1658)
x=np.empty(1001)
x[0]=0
alpha=0.99
T=1000
shocks=np.random.normal(size=1000,scale=0.007)
for t in range(T):
    x[t+1]=x[t]*alpha + shocks[t]
plt.plot(x, label='AR[1]')
plt.legend()
plt.show()

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]

plt.plot(simulated_states, label='tauchen')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states, label='Tauchens')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# They are really not that close, we will later try again with a bigger n, but now let's see how rou does

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]

plt.plot(simulated_states1, label='rouse')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states1, label='Rou')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# it dosnt do very well either

# %%
rho=0.99
n=61

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]

plt.plot(simulated_states, label='tauchen')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states, label='Tauchens')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]

plt.plot(simulated_states1, label='rouse')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,  label='continuos')
ax.plot(simulated_states1, label='Rou')
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$k_t$', fontsize=14)
ax.legend()
plt.show()

# %% [markdown]
# I tried the process with bigger n's and they only started doing good with n>60

# %%
n=9

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]
model = LinearRegression()
model.fit(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.00075947]
# Coefficients: [[0.96999634]]
# coefficient of determination: 0.9408929058420545

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]
model = LinearRegression()
model.fit(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.00045995]
# Coefficients: [[0.98164794]]
# coefficient of determination: 0.963632678253307

# %% [markdown]
# They both did pretty bad comparing the graphs but the rou method did way better in the regressin, lets try with n=61

# %%
n=61

# %%
xgrid = np.linspace(low, upp,n )
trmo=tau(n,rho,sigma,a=low,b=upp)
N = int((n-1)/2)
current_state = np.empty(nsteps+1)
current_state[0] = N
simulated_states = np.zeros(nsteps+1)
simulated_states[0] = 0
trm = np.zeros((n, n+1))
trm[:, 1:] = trmo
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm[int(current_state[i])-1, :]), shocks_cdf[i],side="left")
    current_state[i+1] = next_state_index
    simulated_states[i+1] = xgrid[int(current_state[i+1])-1]
model = LinearRegression()
model.fit(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states[1:].reshape(-1, 1), simulated_states[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.00059841]
# Coefficients: [[0.96743021]]
# coefficient of determination: 0.9359212139703166

# %%
maxi = (sigma**2 / (1 - rho**2))**(1/2) * np.sqrt(n - 1)
mini=-maxi
xgrid1 = np.linspace(mini, maxi, n)
trm1=rouwenhorst(n, rho,sigma)
current_state1 = np.empty(nsteps+1)
current_state1[0] = N
simulated_states1 = np.zeros(nsteps+1)
simulated_states1[0] = 0
trm0 = np.zeros((n, n+1))
trm0[:, 1:] = trm1
for i in range(nsteps-1):
    next_state_index = np.searchsorted(np.cumsum(trm0[int(current_state1[i])-1, :]), shocks_cdf[i],side="left")
    current_state1[i+1] = next_state_index
    simulated_states1[i+1] = xgrid1[int(current_state1[i+1])-1]
model = LinearRegression()
model.fit(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))
r_sq = model.score(simulated_states1[1:].reshape(-1, 1), simulated_states1[:nsteps].reshape(-1, 1))


print('Intercept:', model.intercept_)
print('Coefficients:', model.coef_)
print(f"coefficient of determination: {r_sq}")
# Out:
# Intercept: [-0.00066181]
# Coefficients: [[0.98509481]]
# coefficient of determination: 0.9704117863409146

# %% [markdown]
# Tauchens method did even worse in the regression with a bigger n while rou did even better
